# %% [markdown]
# # EMO-Core v1.0 demo
#
# Small notebook showing how to import the EMO metric modules and UIA engine, and how to call the FastAPI demo endpoints.

# %%
import pandas as pd
from emo.organismality import compute_organismality_index
from emo.gwi import compute_gwi
from emo.info_time import compute_information_time

treaties = pd.DataFrame({"region": ["World"], "treaty_count": [120]})
conflicts = pd.DataFrame({"region": ["World"], "conflict_deaths": [10000]})
oi = compute_organismality_index(treaties, conflicts)
oi
